# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('World Happiness Report.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error      GDP   Family   Health  Freedom  \
# 0              7.587         0.03411  1.39651  1.34951  0.94143  0.66557
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'GDP', 'Family', 'Health', 'Freedom', 'Trust',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Country              0
# Region               0
# Happiness Rank       0
# Happiness Score      0
# Standard Error       0
# GDP                  0
# Family               0
# Health               0
# Freedom              0
# Trust                0
# Generosity           0
# Dystopia Residual    0
# dtype: int64

# %%
df.isnull()
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error    GDP  \
# 0      False   False           False            False           False  False
# 1      False   False           False            False           False  False
# 2      False   False           False            False           False  False
# 3      False   False           False            False           False  False
# 4      False   False           False            False           False  False
# ..       ...     ...             ...              ...             ...    ...
# 153    False   False           False            False           False  False
# 154    False   False           False            False           False  False
# 155    False   False           False            False           False  False
# 156    False   False           False            False           False  False
# 157    False   False           False            False           False  False
#
# ...

# %% [markdown]
# # EDA

# %% [markdown]
# # Scatterplot

# %%
import seaborn as sns

# %%
sns.scatterplot(x='Country',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Happiness Rank',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Happiness Rank', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='GDP',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='GDP', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Health',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Health', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Freedom',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Dystopia Residual',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Happiness Score'>

# %%
import matplotlib.pyplot as plt
sns.pairplot(df)
plt.show()

# %% [markdown]
# # Correlation

# %%
df['Country']=df['Country'].astype('category').cat.codes
df['Region']=df['Region'].astype('category').cat.codes
df.corr()
# Out:
#                     Country    Region  Happiness Rank  Happiness Score  \
# Country            1.000000  0.005092       -0.098538         0.083380
# Region             0.005092  1.000000        0.213773        -0.176791
# Happiness Rank    -0.098538  0.213773        1.000000        -0.992105
# Happiness Score    0.083380 -0.176791       -0.992105         1.000000
# Standard Error     0.033879 -0.022600        0.158516        -0.177254
# GDP                0.037808 -0.260139       -0.785267         0.780966
# Family             0.159416 -0.168533       -0.733644         0.740605
# Health             0.037829 -0.357508       -0.735613         0.724200
# Freedom            0.085684  0.092567       -0.556886         0.568211
# Trust              0.088155  0.165040       -0.372315         0.395199
# Generosity         0.118085  0.273557       -0.160142         0.180319
# Dystopia Residual -0.019778 -0.057276       -0.521999         0.530474
#
# ...

# %%
df.corr()['Happiness Score'].sort_values()
# Out:
# Happiness Rank      -0.992105
# Standard Error      -0.177254
# Region              -0.176791
# Country              0.083380
# Generosity           0.180319
# Trust                0.395199
# Dystopia Residual    0.530474
# Freedom              0.568211
# Health               0.724200
# Family               0.740605
# GDP                  0.780966
# Happiness Score      1.000000
# Name: Happiness Score, dtype: float64

# %% [markdown]
# Correlation using heatmap

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(), annot=True, linewidths=0.5, linecolor='black', fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Outcome of Correlation

# %% [markdown]
# 1. Country has only 8.4 percent correlation with target which is a weak bond
# 2. Region has -17.7 percent correlation with target which is a very weak bond.
# 3. Happiness Rank has -99 percent correlation with target which is a very weak bond.
# 4. Standard error has -17 percent correlation with target which is a very weak bond.
# 5. GDP ha 78 percent correlation with the target which is a strong bond.
# 6. Family has 74 percent correlation with target which is a strong bond.
# 7. Health has 72 percent correlation with target which is a strong bond.
# 8. Freedom has 56 percent correlation with target which is a good bond.
# 9. Trust has 40 percent correlation with target which is a good bond.
# 10. Generosity has 19 percent correlation with target which is satisfactory.
# 11. Dystopia Residual has 53 percent correlation with target which is a good bond

# %% [markdown]
# Max Correlation : GDP
#
# Min Correlation : Happiness Rank

# %% [markdown]
# # Descriptive Statistics

# %%
df.describe()
# Out:
#           Country      Region  Happiness Rank  Happiness Score  \
# count  158.000000  158.000000      158.000000       158.000000
# mean    78.500000    5.120253       79.493671         5.375734
# std     45.754781    2.993321       45.754363         1.145010
# min      0.000000    0.000000        1.000000         2.839000
# 25%     39.250000    3.000000       40.250000         4.526000
# 50%     78.500000    4.500000       79.500000         5.232500
# 75%    117.750000    8.000000      118.750000         6.243750
# max    157.000000    9.000000      158.000000         7.587000
#
#        Standard Error         GDP      Family      Health     Freedom  \
# count      158.000000  158.000000  158.000000  158.000000  158.000000
# mean         0.047885    0.846137    0.991046    0.630259    0.428615
# std          0.017146    0.403121    0.272369    0.247078    0.150693
# min          0.018480    0.000000    0.000000    0.000000    0.000000
# ...

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:],2),linewidth=2, annot=True, fmt='.2f')
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title("Variables summary")
plt.show()

# %% [markdown]
# # Outcome of description

# %% [markdown]
# From the above plotting we are determining mean, standard deviation, minimum and maximum value of each column.
#
# Total number of rows in the dataset:
#
#     1. 158 rows
#     2. 12 columns
#
# Country:
#
#     1. Mean=78.5
#     2. std=45.75
#     3. max value=157
#     4. min value=0
#
# Region:
#
#     1. Mean=5.12
#     2. std=2.99
#     3. max value=9
#     4. min value=0
#
# Happiness Rank:
#
#     1. Mean=79.4
#     2. std=45.75
#     3. max value=158
#     4. min value=1
#
# Standard Error:
#
#     1. Mean=0.05
#     2. std=0.02
#     3. max value=0.14
#     4. min value=0.02
#
# GDP:
#
#     1. Mean=0.85
#     2. std=0.40
#     3. max value=1.69
#     4. min value=0
#
# Family:
#
#     1. Mean=0.99
#     2. std=0.28
#     3. max value=1.40
#     4. min value=0
#
# Health:
#
#     1. Mean=0.63
#     2. std=0.25
#     3. max value=1.02
#     4. min value=0
#
# Freedom:
#
#     1. Mean=0.43
#     2. std=0.15
#     3. max value=0.66
#     4. min value=0
#
# Trust:
#
#     1. Mean=0.14
#     2. std=0.12
#     3. max value=0.55
#     4. min value=0
#
# Generosity:
#
#     1. Mean=0.23
#     2. std=0.12
#     3. max value=0.79
#     4. min value=0
#
# Dystopia Residual:
#
#     1. Mean=2.09
#     2. std=0.55
#     3. max value=3.6
#     4. min value=0.32

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            158 non-null    int16
#  1   Region             158 non-null    int8
#  2   Happiness Rank     158 non-null    int64
#  3   Happiness Score    158 non-null    float64
#  4   Standard Error     158 non-null    float64
#  5   GDP                158 non-null    float64
#  6   Family             158 non-null    float64
#  7   Health             158 non-null    float64
#  8   Freedom            158 non-null    float64
#  9   Trust              158 non-null    float64
#  10  Generosity         158 non-null    float64
#  11  Dystopia Residual  158 non-null    float64
# dtypes: float64(9), int16(1), int64(1), int8(1)
# memory usage: 12.9 KB

# %% [markdown]
# From the above code we can have the columns datatype and memory used by the dataframe.

# %% [markdown]
# # Outliers checking:

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df.plot(kind='box', subplots=True, layout=(3,4), figsize=(10,10))
# Out:
# Country                 AxesSubplot(0.125,0.657941;0.168478x0.222059)
# Region               AxesSubplot(0.327174,0.657941;0.168478x0.222059)
# Happiness Rank       AxesSubplot(0.529348,0.657941;0.168478x0.222059)
# Happiness Score      AxesSubplot(0.731522,0.657941;0.168478x0.222059)
# Standard Error          AxesSubplot(0.125,0.391471;0.168478x0.222059)
# GDP                  AxesSubplot(0.327174,0.391471;0.168478x0.222059)
# Family               AxesSubplot(0.529348,0.391471;0.168478x0.222059)
# Health               AxesSubplot(0.731522,0.391471;0.168478x0.222059)
# Freedom                    AxesSubplot(0.125,0.125;0.168478x0.222059)
# Trust                   AxesSubplot(0.327174,0.125;0.168478x0.222059)
# Generosity              AxesSubplot(0.529348,0.125;0.168478x0.222059)
# Dystopia Residual       AxesSubplot(0.731522,0.125;0.168478x0.222059)
# dtype: object

# %% [markdown]
# From the above outcome we can see that, columns[Standars Error, Family, Trust, Generosity, Dystopia residual] has outliers.

# %% [markdown]
# # Skewness

# %%
df.skew()
# Out:
# Country              0.000000
# Region              -0.116119
# Happiness Rank       0.000418
# Happiness Score      0.097769
# Standard Error       1.983439
# GDP                 -0.317575
# Family              -1.006893
# Health              -0.705328
# Freedom             -0.413462
# Trust                1.385463
# Generosity           1.001961
# Dystopia Residual   -0.238911
# dtype: float64

# %% [markdown]
# Outcome of the skewness:
#
# Skewness threshold is taken is +-0.65.
#
# Therefore, columns[Standard Error, Family, Health, Trust, Generosity], are having skewness.

# %% [markdown]
# # Normal Distribution Curve:

# %%
sns.distplot(df['Country'])
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Density'>

# %%
sns.distplot(df['Region'])
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Density'>

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'GDP', 'Family', 'Health', 'Freedom', 'Trust',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
sns.distplot(df['Happiness Rank'])
# Out:
# <AxesSubplot:xlabel='Happiness Rank', ylabel='Density'>

# %%
sns.distplot(df['Standard Error'])
# Out:
# <AxesSubplot:xlabel='Standard Error', ylabel='Density'>

# %%
sns.distplot(df['GDP'])
# Out:
# <AxesSubplot:xlabel='GDP', ylabel='Density'>

# %%
sns.distplot(df['Family'])
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Density'>

# %%
sns.distplot(df['Health'])
# Out:
# <AxesSubplot:xlabel='Health', ylabel='Density'>

# %%
sns.distplot(df['Freedom'])
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Density'>

# %%
sns.distplot(df['Trust'])
# Out:
# <AxesSubplot:xlabel='Trust', ylabel='Density'>

# %%
sns.distplot(df['Generosity'])
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Density'>

# %%
sns.distplot(df['Dystopia Residual'])
# Out:
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Density'>

# %% [markdown]
# # Removing Outliers

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))
z.shape
# Out:
# (158, 12)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64), array([ 9,  4,  4,  4, 10,  6,  9, 11,  6], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
print("Old Dataframe", df.shape)
print("New Dataframe", df_new.shape)
print("total_dropped_rows", df.shape[0] - df_new.shape[0])
# Out:
# Old Dataframe (158, 12)
# New Dataframe (149, 12)
# total_dropped_rows 9

# %% [markdown]
# # Percentage Data Loss:

# %%
loss_percent=(158-149)/158*100
print(loss_percent, '%')
# Out:
# 5.69620253164557 %

# %%
# independent columns
x=df.drop('Happiness Score',axis=1)

# %%
# target column
y=df['Happiness Score']

# %% [markdown]
# # Transforming data to remove skewness

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
x
# Out:
# array([[ 1.17106926,  1.24453048, -2.06341393, ...,  1.77399061,
#          0.62239051,  0.75099154],
#        [-0.3443269 ,  1.24453048, -2.00849761, ...,  0.31599326,
#          1.48099498,  1.11001108],
#        [-0.84509236,  1.24453048, -1.95857395, ...,  1.90679207,
#          0.92797276,  0.70227525],
#        ...,
#        [ 1.18876946, -0.30300992,  1.52535242, ...,  0.73891461,
#          1.65933595, -2.86621557],
#        [-1.28332767,  0.95510156,  1.54254416, ..., -0.15194624,
#         -0.19482942, -0.51480136],
#        [ 1.27672507,  0.95510156,  1.55970548, ..., -0.06732623,
#         -0.49041465, -0.97664547]])

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 1.17106926,  1.24453048, -2.06341393, ...,  1.77399061,
#          0.62239051,  0.75099154],
#        [-0.3443269 ,  1.24453048, -2.00849761, ...,  0.31599326,
#          1.48099498,  1.11001108],
#        [-0.84509236,  1.24453048, -1.95857395, ...,  1.90679207,
#          0.92797276,  0.70227525],
#        ...,
#        [ 1.18876946, -0.30300992,  1.52535242, ...,  0.73891461,
#          1.65933595, -2.86621557],
#        [-1.28332767,  0.95510156,  1.54254416, ..., -0.15194624,
#         -0.19482942, -0.51480136],
#        [ 1.27672507,  0.95510156,  1.55970548, ..., -0.06732623,
#         -0.49041465, -0.97664547]])

# %% [markdown]
# # Here we will use Linear Regression model

# %%
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
x.shape
# Out:
# (158, 11)

# %%
y.shape
# Out:
# (158,)

# %%
lr=LinearRegression()

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.20)
lr.fit(x_train,y_train)
pred_test=lr.predict(x_test)

# %%
pred_test
# Out:
# array([4.02082695, 6.15840915, 4.14224641, 3.24419725, 4.7898805 ,
#        6.62669336, 4.93626797, 4.71016642, 4.90963513, 3.94031847,
#        6.85697481, 5.78257185, 7.05589395, 5.51604783, 6.81404914,
#        6.57925514, 4.51072728, 4.63027417, 5.03924179, 5.65539803,
#        3.68569091, 6.98593289, 7.24435707, 7.32298037, 6.50169807,
#        5.14769041, 5.90129355, 3.90502621, 4.23545403, 3.70672933,
#        3.75196901, 5.31156768])

# %%
lr.coef_
# Out:
# array([ 0.00298038, -0.02367491, -0.32852471, -0.00747937,  0.29773028,
#         0.20196783,  0.16314398,  0.10092052,  0.05379692,  0.07088438,
#         0.38423259])

# %%
lr.intercept_
# Out:
# 5.374281425023085

# %%
lr.score(x_train,y_train)
# Out:
# 0.9942239858052722

# %% [markdown]
# That is, approximately the model is working 99 percent

# %%
pred_test=lr.predict(x_test)
print('Predicted happiness score:', pred_test)
print('Actual happiness score:', y_test)
# Out:
# Predicted happiness score: [4.02082695 6.15840915 4.14224641 3.24419725 4.7898805  6.62669336
#  4.93626797 4.71016642 4.90963513 3.94031847 6.85697481 5.78257185
#  7.05589395 5.51604783 6.81404914 6.57925514 4.51072728 4.63027417
#  5.03924179 5.65539803 3.68569091 6.98593289 7.24435707 7.32298037
#  6.50169807 5.14769041 5.90129355 3.90502621 4.23545403 3.70672933
#  3.75196901 5.31156768]
# Actual happiness score: 128    4.307
# 45     5.987
# 134    4.194
# 156    2.905
# 90     5.057
# 29     6.574
# 96     4.898
# 98     4.876
# 95     4.949
# 140    3.931
# 19     6.901
# 56     5.828
# 15     6.983
# 69     5.548
# 24     6.786
# 30     6.505
# 122    4.507
# 109    4.686
# 93     4.971
# 65     5.695
# 150    3.655
# 18     6.937
# 12     7.200
# 9      7.284
# 31     6.485
# 81     5.192
# 51     5.889
# 139    3.956
# 125    4.369
# 146    3.681
# 145    3.781
# 75     5.332
# Name: Happiness Score, dtype: float64

# %%
print('Error:')
print("Mean absolute error:",mean_absolute_error (y_test,pred_test))
print("Mean squared error:" ,mean_squared_error(y_test,pred_test))
print('Root Mean Squared Error:' ,np.sqrt(mean_squared_error(y_test, pred_test)))
# Out:
# Error:
# Mean absolute error: 0.07440644486005221
# Mean squared error: 0.0122279276947659
# Root Mean Squared Error: 0.1105799606382906

# %%
from sklearn.metrics import r2_score
print(r2_score (y_test, pred_test))
# Out:
# 0.9913812004141486

# %%
from sklearn.model_selection import cross_val_score

# %%
scores=cross_val_score(lr, x_train, y_train, scoring='r2', cv=5)

# %%
scores
# Out:
# array([0.99603545, 0.99462117, 0.97970542, 0.99329443, 0.98890602])
